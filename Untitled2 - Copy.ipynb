# %% [markdown]
# ## P3: Wrangling with OpenStreetMap Data
#
# OpenStreetMap is an open source project, contains a large number of city maps where users can add, remove and edit local places and streets. It is directly connected with Google Maps which would help improving maps.
# The challange is to insure the correctency and constincy of the provided dataset.
#
# In this project, Southampton street map is analysed which it's size is over 45 MB as requested. I have chose this city because I have been there and I loved it.
#
# Southamptom dataset is available to download from: https://mapzen.com/data/metro-extracts/metro/southampton_england/

# %% [markdown]
# #this tag to load py into Jupyter and run against the dataset: %load mapparser.py

# %%
#%load mapparser.py
"""""
1- find documentatin of osm xml format in wiki
    https://wiki.openstreetmap.org/wiki/Main_Page
    http://wiki.openstreetmap.org/wiki/OSM_XML
"""""
import xml.etree.ElementTree as ET
import pprint

OSM_FILE='southampton.osm'

def count_tags(filename):
    tag_count = {}
    for _, element in ET.iterparse(filename, events=("start",)):
        add_tag(element.tag, tag_count)
    return tag_count

def add_tag(tag, tag_count):
    if tag in tag_count:
        tag_count[tag] += 1
    else:
        tag_count[tag] = 1

def test():

    tags = count_tags(OSM_FILE)
    pprint.pprint(tags)
    """
    assert tags == {'bounds': 1,
                     'member': 3,
                     'nd': 4,
                     'node': 20,
                     'osm': 1,
                     'relation': 1,
                     'tag': 7,
                     'way': 1}

    """

if __name__ == "__main__":
    print ("Conut tags in southampton.osm")
    test()
# Out:
# Conut tags in southampton.osm
# {'bounds': 1,
#  'member': 12072,
#  'nd': 375357,
#  'node': 272642,
#  'osm': 1,
#  'relation': 1175,
#  'tag': 204363,
#  'way': 51358}

# %%
#%load users.py

import xml.etree.ElementTree as ET
import pprint
import re
"""
Your task is to explore the data a bit more.
The first task is a fun one - find out how many unique users
have contributed to the map in this particular area!

The function process_map should return a set of unique user IDs ("uid") and user
"""

def get_user(element):
    return


def process_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        if 'uid' in element.attrib:
            users.add(element.get('user'))
            users.add(element.get('uid'))

    return users


def test():
    users = process_map('southampton.osm')
    pprint.pprint(users)
    #assert len(users) == 6



if __name__ == "__main__":
    test()
# Out:
# {'0123456789',
#  '100597',
#  '101043',
#  '101150',
#  '1030',
#  '103253',
#  '104459',
#  '1051550',
#  '1061999',
#  '106914',
#  '107237',
#  '107617',
#  '10845',
#  '10983',
#  '110263',
#  '111135',
#  '11126',
#  '113818',
#  '1150946',
#  '1158381',
#  '115894',
#  '1164',
#  '1165720',
#  '116727',
#  '116979',
#  '117013',
#  '118021',
#  '1185',
#  '120664',
#  '1213696',
#  '1214803',
#  '1217467',
#  '1221633',
#  '1233572',
#  '124414',
#  '1244489',
#  '124550',
#  '1246157',
#  '1246869',
#  '1249205',
#  '12660',
#  '12671',
#  '127060',
#  '128186',
#  '128322',
#  '1293386',
#  '12935',
#  '1295',
#  '12992',
#  '13013',
#  '1302643',
#  '131236',
#  '13203',
#  '13241',
#  '132439',
#  '133272',
#  '13334',
#  '134778',
#  '1362674',
#  '1362708',
#  '1362719',
#  '1362734',
#  '1362779',
#  '1365690',
#  '1366222',
#  '1369743',
#  '14020',
#  '1404136',
#  '141442',
#  '1425497',
#  '1428769',
#  '145231',
#  '1473',
#  '1474063',
#  '1479299',
#  '14846',
#  '1497116',
#  '1518807',
#  '152289',
#  '152305',
#  '1534261',
#  '1540938',
#  '154584',
#  '156284',
#  '1566',
#  '1566481',
#  '1569426',
#  '1589260',
#  '159575',
#  '161619',
#  '1617449',
#  '1645131',
#  '1649378',
#  '167108',
#  '1679',
#  '1694420',
#  '1697',
#  '1701064',
#  '172180',
#  '17292',
#  '1730273',
#  '174',
#  '174796',
#  '1761984',
#  '1765452',
#  '1775426',
#  '1776322',
#  '1778799',
#  '178186',
#  '1783785',
#  '1796809',
#  '1803771',
#  '18069',
#  '1807121',
#  '181135',
#  '1822638',
#  '182738',
#  '1829683',
#  '1834625',
#  '1852761',
#  '1863557',
#  '186702',
#  '187157',
#  '1885407',
#  '189782',
#  '190869',
#  '1911497',
#  '1915697',
#  '1927071',
#  '1936689',
#  '194642',
#  '194743',
#  '1956376',
#  '1962477',
#  '1964778',
#  '196654',
#  '1979489',
#  '1AndyG',
#  '201095',
#  '2020',
#  '2021148',
#  '2028836',
#  '2051380',
#  '205666',
#  '2070600',
#  '2071436',
#  '2094575',
#  '2098',
#  '210115',
#  '2102783',
#  '21189',
#  '21244',
#  '2144605',
#  '2148680',
#  '2154858',
#  '2155237',
#  '2161186',
#  '21705',
#  '2184348',
#  '21931',
#  '2219338',
#  '2220958',
#  '2226712',
#  '2231',
#  '2245260',
#  '2248331',
#  '2274',
#  '227715',
#  '2281266',
#  '229770',
#  '2299575',
#  '23022',
#  '23024',
#  '231477',
#  '2317343',
#  '2327823',
#  '234203',
#  '2346668',
#  '2347729',
#  '237465',
#  '237737',
#  '237926',
#  '2387',
#  '2406578',
#  '2411516',
#  '24119',
#  '24126',
#  '242798',
#  '243152',
#  '2435408',
#  '2483858',
#  '2484479',
#  '2486979',
#  '2487553',
#  '2489541',
#  '2498528',
#  '2506299',
#  '2511013',
#  '2511706',
#  '2512300',
#  '2516187',
#  '25504',
#  '2551296',
#  '2552953',
#  '2560081',
#  '2565445',
#  '257606',
#  '2580104',
#  '260271',
#  '260682',
#  '2618950',
#  '26299',
#  '263130',
#  '2666394',
#  '2676985',
#  '2723425',
#  '2729557',
#  '2740122',
#  '2748195',
#  '2774223',
#  '2812014',
#  '281267',
#  '2812670',
#  '2814467',
#  '2835928',
#  '28399',
#  '2853102',
#  '2860951',
#  '28678',
#  '286907',
#  '28794',
#  '290680',
#  '2908206',
#  '2912335',
#  '29370',
#  '2966270',
#  '2982899',
#  '2bob',
#  '302319',
#  '30525',
#  '30587',
#  '306096',
#  '30636',
#  '3066734',
#  '3069260',
#  '3080577',
#  '3099236',
#  '3112087',
#  '311722',
#  '3140760',
#  '314635',
#  '31491',
#  '3164012',
#  '3178375',
#  '320501',
#  '322785',
#  '3244052',
#  '3244319',
#  '3267319',
#  '32786',
#  '329877',
#  '330579',
#  '3321755',
#  '3328644',
#  '334120',
#  '334129',
#  '3352295',
#  '3366412',
#  '339551',
#  '339581',
#  '34009',
#  '340498',
#  '3422',
#  '34227',
#  '3432400',
#  '343319',
#  '344561',
#  '3454624',
#  '34580',
#  '346039',
#  '346601',
#  '346873',
#  '348029',
#  '349727',
#  '3516',
#  '35271',
#  '353663',
#  '3545505',
#  '354996',
#  '3551979',
#  '3563046',
#  '3582',
#  '358761',
#  '360392',
#  '360562',
#  '3630816',
#  '364',
#  '364587',
#  '3649042',
#  '365705',
#  '3666419',
#  '367225',
#  '3673505',
#  '37608',
#  '3761378',
#  '38239',
#  '384887',
#  '38588',
#  '3918453',
#  '3937',
#  '39457',
#  '396743',
#  '39688',
#  '396978',
#  '397946',
#  '3984',
#  '402144',
#  '406589',
#  '4081914',
#  '411783',
#  '4140892',
#  '414611',
#  '416423',
#  '419772',
#  '42123',
#  '422996',
#  '4247',
#  '433361',
#  '436133',
#  '436419',
#  '436930',
#  '437598',
#  '43889',
#  '44221',
#  '445666',
#  '445671',
#  '451479',
#  '452319',
#  '4534155',
#  '45399',
#  '458747',
#  '459739',
#  '45degN',
#  '46510',
#  '465445',
#  '467789',
#  '4723080',
#  '474225',
#  '4772',
#  '477798',
#  '4787375',
#  '4794609',
#  '4806534',
#  '4848888',
#  '493595',
#  '4951',
#  '496770',
#  '4982165',
#  '4Ms',
#  '5008136',
#  '5011474',
#  '50174',
#  '508',
#  '5083357',
#  '51045',
#  '5121',
#  '5164',
#  '51722',
#  '5172366',
#  '5188597',
#  '5189852',
#  '519501',
#  '5233411',
#  '524500',
#  '5247086',
#  '526976',
#  '52797',
#  '5302564',
#  '5317899',
#  '533465',
#  '534393',
#  '5359',
#  '53724',
#  '5380763',
#  '540739',
#  '5449606',
#  '5451616',
#  '5452',
#  '5454915',
#  '547352',
#  '55129',
#  '553286',
#  '5541',
#  '5542',
#  '55430',
#  '55782',
#  '562640',
#  '565478',
#  '571483',
#  '572167',
#  '573255',
#  '57737',
#  '57884',
#  '58255',
#  '585447',
#  '589596',
#  '5926',
#  '593937',
#  '60395',
#  '605122',
#  '607399',
#  '609732',
#  '61216',
#  '613772',
#  '616774',
#  '61941',
#  '61942',
#  '62352',
#  '623842',
#  '632087',
#  '633351',
#  '6367',
#  '63807',
#  '645127',
#  '64672',
#  '652425',
#  '6634',
#  '663979',
#  '670691',
#  '674150',
#  '67862',
#  '682629',
#  '684232',
#  '687237',
#  '689321',
#  '692602',
#  '70',
#  '700263',
#  '700301',
#  '703002',
#  '7037',
#  '705850',
#  '706170',
#  '70696',
#  '711187',
#  '712804',
#  '713665',
#  '716353',
#  '7203',
#  '722137',
#  '735',
#  '736',
#  '7428',
#  '7437',
#  '74897',
#  '752242',
#  '754424',
#  '76002',
#  '76617',
#  '770155',
#  '77114',
#  '78656',
#  '790848',
#  '802554',
#  '807655',
#  '81429',
#  '82264',
#  '827651',
#  '82820',
#  '830558',
#  '831743',
#  '8339',
#  '84000',
#  '8422',
#  '84263',
#  '84681',
#  '84724',
#  '85218',
#  '86',
#  '86504',
#  '869400',
#  '870861',
#  '873940',
#  '87632',
#  '88164',
#  '8857',
#  '91225',
#  '917436',
#  '92274',
#  '93583',
#  '935865',
#  '94',
#  '94346',
#  '944957',
#  '950182',
#  '972618',
#  '985355',
#  '98682',
#  '98717',
#  '99091',
#  '99139',
#  '99999',
#  'ADMcD',
#  'ADietrich',
#  'AMB',
#  'Acslo',
#  'Alan Jerram',
#  'Alastair Mogford',
#  'Aleks-Berlin',
#  'Alex123',
#  'Andy Kinge',
#  'Andy Street',
#  'Andy_Moo',
#  'Andy_traveline',
#  'AnkEric',
#  'Anton Piatek',
#  'ApplesAndTheCIty',
#  'Arjan Sahota',
#  'Azquelt',
#  'BCNorwich',
#  'BIL9055',
#  'BXS',
#  'Basirk',
#  'Ben',
#  'Ben Makin',
#  'BharataHS',
#  'BiIbo',
#  'BillHall',
#  'Blackhill',
#  'Blind',
#  'BotleyBoy',
#  'Bowen13',
#  'Boyo',
#  'Bramble',
#  'Brambles',
#  'Broken Star',
#  'CGT',
#  'CatSpring',
#  'Cde DBD',
#  'Cebderby',
#  'Chewett',
#  'ChinnorBoy',
#  'Chris Baines',
#  'Chris Clemson',
#  'Chris Dennis',
#  'Chris Parker',
#  'Chris Stone',
#  'Christian Ledermann',
#  'Claudius Henrichs',
#  'Cloud-Wine',
#  'Cradamy',
#  'Curtis3250692',
#  'CycleStreets',
#  'Daeron',
#  'DanGregory',
#  'Dave2012',
#  'DaveF',
#  'David_UK',
#  'DdA_Design',
#  'Deanna Earley',
#  'Dima M',
#  'Dominicleedade',
#  'DrMark',
#  'Dragons8mycat',
#  'Duppy',
#  'Easy Rambler',
#  'EdLoach',
#  'EddSeabrook',
#  'Edward',
#  'ElHickmano',
#  'Ele Pilgrim',
#  'EoghanM',
#  'Eric Reed',
#  'Eskriett',
#  'Exosmapper',
#  'FahRadler',
#  'Filstaz',
#  'FlamingTempura',
#  'Fr3d_org',
#  'FvGordon',
#  'GaryReggae',
#  'Gavaasuren',
#  'General Dreedle',
#  'Geogast',
#  'Gerd Fahrenhorst',
#  'GerdP',
#  'GinaroZ',
#  'GlasgowBoy95',
#  'Gordon Fox',
#  'Gregory Williams',
#  'Guy',
#  'Gweglez',
#  'Hardo66',
#  'Harjit (CabMyRide)',
#  'Harry Cutts',
#  'Head',
#  'Heajeong',
#  'Heliomance',
#  'HencoAppel',
#  'Hilton Worldwide',
#  'Hobgoblin',
#  'HolgerJeromin',
#  'Homme',
#  'HovisCoder',
#  'Howie_HCA',
#  'Ian Millard',
#  'Iced',
#  'IknowJoseph',
#  'Incanus_uk',
#  'IndyMapper',
#  'JBYO62',
#  'JBattersby',
#  'JTDavis',
#  'JWoosh',
#  'JamesKingdom',
#  'Jan Coombs',
#  'JayTurnr',
#  'Jedrzej Pelka',
#  'Jeffpike25',
#  'Jeremy Morley',
#  'JinC',
#  'Jo2Builder',
#  'Johalareewi',
#  'John Muddle',
#  'Jonathan Stott',
#  'Joshallen23',
#  'Julianc',
#  'KAAAA',
#  'Kanenas',
#  'Kevin Verdon',
#  'Kevin-Rong',
#  'Kuldip (CabMyRide)',
#  'Kyle69',
#  'LLAQWA',
#  'Lard',
#  'LeTopographeFou',
#  'Lee Bumstead',
#  'Les Harris',
#  'Lifechooser',
#  'Little Brother',
#  'Lloyd Pearson',
#  'Lorangar',
#  'Luis36995',
#  'Madryn',
#  'Makie',
#  'Manu1400',
#  'Manuel Timita',
#  'MapMarkyloo',
#  'MapperTwo',
#  'Mappernerd',
#  'MarcinLukasz',
#  'Mark Lidstone',
#  'Mark_S',
#  'Markus59',
#  'Math1985',
#  'Matt',
#  'Mauls',
#  'Med',
#  'MeganSouthampton',
#  'Mentz GmbH',
#  'Mezzanine',
#  'Michal Krompiec',
#  'Mike Baggaley',
#  'MikeLM',
#  'Milliams',
#  'MintMark',
#  'Moleole',
#  'Morrishey',
#  'Mr W 93',
#  'Muzer',
#  'NaPTAN',
#  'Nateleigh',
#  'Neil C',
#  'Netzwolf',
#  'Nick Austin',
#  'Norfolkadam',
#  'OMME-OSM',
#  'OSMF Redaction Account',
#  'Open Source Fan',
#  'Pafnutij',
#  'Paul Webb',
#  'PealRinger',
#  'Persicoana',
#  'Pete Owens',
#  'Peter Silvester',
#  'PeterEastern',
#  'PeterOlding',
#  'PeterParslow',
#  'Phil Amy',
#  'Phil Wu',
#  'Philbeech1',
#  'Picaboo',
#  'PikarinePlays',
#  'Pingu',
#  'PmaiIkeey',
#  'ProfIanR',
#  'R0bst3r',
#  'RAW',
#  'Rain Thief',
#  'Ralphcb',
#  'RichRico',
#  'RitterR',
#  'River Sales & Lettings',
#  'Ro Sun',
#  'RobACollins',
#  'Robbie Francis',
#  'Robert Stocks',
#  'Robert Whittaker',
#  'Ropino',
#  'Rowland',
#  'Rudolf Mayer',
#  'Rupert B Puppenstein',
#  'Russ McD',
#  'Russell Bernstein',
#  'SERPRO',
#  'SK53',
#  'STAXR36',
#  'Sailor Steve',
#  'Sal73x',
#  'SamirLSN',
#  'Scott Flood',
#  'SebaKunze',
#  'SergeiChe',
#  'Shepard',
#  'SiHollett',
#  'Smiley Hairy Camera Guy',
#  'Snorfalorpagus',
#  'Socks',
#  'SolentRoger',
#  'SomePlaceMapperCT',
#  'SomeoneElse',
#  'SomeoneElse_Revert',
#  'SotonLampie',
#  'SteakAndEggs',
#  'Steeley',
#  'SteffenS',
#  'Stephen Pipes',
#  'Steve Chilton',
#  'Steve Goodey',
#  'StevePO16',
#  'Stevio',
#  'Stiev Severecci',
#  'Stéphane Péchard',
#  'TForbes',
#  'Tallguy',
#  'TechnoFreak',
#  'The Islander',
#  'The Maarssen Mapper',
#  'TheaC',
#  'Thomas8122',
#  'Thomas_123',
#  'ToffeHoff',
#  'Toffer12',
#  'TrishiaStar',
#  'TurquoiseJ',
#  'UniEagle',
#  'Violaine_Do',
#  'Volker Fröhlich',
#  'Vzzbux',
#  'Walter Schlögl',
#  'Warmtoe',
#  'Welshie',
#  'Who_Is_Joseph',
#  'WilsonMassie',
#  'Wolthusen',
#  'Woodfalls',
#  'Yorvik Prestigitator',
#  'Zamzara',
#  'aarhus',
#  'aceman444',
#  'aclucas',
#  'acslo1',
#  'adimote',
#  'adjuva',
#  'adrianosmond',
#  'adventuresandsuch',
#  'agentgonzo',
#  'amm',
#  'andrewpmk',
#  'andypreece',
#  'aplatts',
#  'artfur plan',
#  'avantman42',
#  'aytfadc',
#  'bahnpirat',
#  'blackadder',
#  'bluemonki',
#  'bornslippy',
#  'botdidier2020',
#  'brianburnell',
#  'burto',
#  'bvivi',
#  'c2r',
#  'calfarome',
#  'caryDing',
#  'catalin_groza',
#  'cgu66',
#  'cgutteridge',
#  'choess',
#  'colindt',
#  'colortitian',
#  'comsomol',
#  'corrigami',
#  'country_wide',
#  'csdf',
#  'ctc1646',
#  'danidoedel',
#  'dankarran',
#  'dannykath',
#  'davidearl',
#  'dcp',
#  'demonghost123',
#  'dforsi',
#  'dh1s07',
#  'diocles',
#  'dmgroom',
#  'dmgroom_coastlines',
#  'dmgroom_ct',
#  'domig1047',
#  'doug_sfba',
#  'droep',
#  'duncaninnes',
#  'duncanmcbryde',
#  'ecmarsden',
#  'eduardo-pedro',
#  'ehm1806',
#  'elbatrop',
#  'fanatik',
#  'finnr',
#  'fishter',
#  'fitzsimons',
#  'flierfy',
#  'fumpel',
#  'gMe',
#  'gkaratziolas',
#  'gormur',
#  'griggy',
#  'grisk',
#  'gsb106',
#  'hairywill',
#  'haytigran',
#  'highflying',
#  'hofoen',
#  'holdend',
#  'hormon',
#  'hornbydd2',
#  'hothedgehog',
#  'iceman-uk',
#  'iwhs',
#  'jamrogers',
#  'jarheadd',
#  'jc67',
#  'jezza0',
#  'jjrscott',
#  'jmsierra',
#  'jmw20',
#  'jnut77',
#  'joakimfors',
#  'jonnyh',
#  'jpd',
#  'jpennycook',
#  'jrheath',
#  'jskeates',
#  'juhanjuku',
#  'jw08v',
#  'kablesingh',
#  'karitotp',
#  'katyakoval',
#  'kennioje',
#  'kingsiwel',
#  'kjbeee',
#  'kkevinmcgrath',
#  'kurtd4',
#  'lg08',
#  'lxbarth',
#  'mackerski',
#  'maggot27',
#  'mahahahaneapneap',
#  'malcolmh',
#  'manof25',
#  'manor09',
#  'marcus2076',
#  'mart13',
#  'mattdymott',
#  'maxerickson',
#  'mboeringa',
#  'mdk',
#  'mdt3k',
#  'mentor',
#  'messpert',
#  'micha_k',
#  'midlandsdave',
#  'mike l',
#  'mimaison',
#  'mjmm17',
#  'mnb20',
#  'monxton',
#  'mtmail',
#  'mueschel',
#  'murble',
#  'nadjim',
#  'ndm',
#  'neiljp',
#  'nickb',
#  'nickw',
#  'nikhilprabhakar',
#  'nixxiepixx',
#  'njb',
#  'njd27',
#  'nyuriks',
#  'oljica',
#  'opani',
#  'p10',
#  'parukhin',
#  'patchjeffa',
#  'paulellery',
#  'pavlina88',
#  'pcman1985',
#  'perros',
#  'peter_2011',
#  'petzlux',
#  'pfbray',
#  'philipcullen',
#  'phobie-odbl',
#  'pmailkeey',
#  'pwc101',
#  'raiment57',
#  'rbarlow',
#  'rbuch703',
#  'red_xanadu',
#  'rh205',
#  'rickburt',
#  'rjhsoton',
#  'rjwilmsi',
#  'robbieonsea',
#  'robbob700',
#  'robert',
#  'robintw147',
#  'robw',
#  'rocketnelly',
#  'rparrygbr',
#  'salix01',
#  'samely',
#  'samhedgerows',
#  'sarahgeijsels',
#  'seav',
#  'seumas',
#  'sfcmap',
#  'shitworth',
#  'shravan91',
#  'sinh',
#  'sladen',
#  'smb1001',
#  'smiker',
#  'snodnipper',
#  'southerner',
#  'southglos',
#  'spark',
#  'stevexyg',
#  'tarats',
#  'tms13',
#  'tomkeogh',
#  'trigpoint',
#  'trungdong',
#  'uboot',
#  'untitled',
#  'urViator',
#  'urbanrambler1',
#  'urzzz1871',
#  'user_5121',
#  'user_5359',
#  'user_5452',
#  'user_5541',
#  'v-na-more',
#  'vahid ahyayi',
#  'waggers',
#  'waldekcycu',
#  'webmink',
#  'werner2101',
#  'wh68',
#  'wheelmap_android',
#  'wheelmap_visitor',
#  'whistlerxp',
#  'wongataa',
#  'woodpeck',
#  'woodpeck_repair',
#  'wrokred',
#  'wugauwgaiwf',
#  'wvdp',
#  'ww9980',
#  'xeodus94',
#  'xybot',
#  'zauron',
#  'Åndrew'}

# %%
# %load tags.py

import xml.etree.ElementTree as ET
import pprint
import re


lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


def key_type(element, keys):
    """ 
    Count the criteria in dictionary for the content of the tag.
    """
    if element.tag == "tag":
        if lower.search(element.attrib['k']):
            keys['lower'] +=1
        elif lower_colon.search(element.attrib['k']):
            keys['lower_colon']+=1
        elif problemchars.search(element.attrib['k']):
            keys['problemchars']+=1
        else:
            keys['other']+=1
        
    return keys



def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys



def test():
    # You can use another testfile 'map.osm' to look at your solution
    # Note that the assertions will be incorrect then.
    keys = process_map('southampton.osm')
    pprint.pprint(keys)
#     assert keys == {'lower': 5, 'lower_colon': 0, 'other': 2, 'problemchars': 0}


if __name__ == "__main__":
    test()
# Out:
# {'lower': 110892, 'lower_colon': 90941, 'other': 2528, 'problemchars': 2}

# %%
#%load audit_street.py
"""
2- AUDIT DATA - Street names

"""	

import xml.etree.cElementTree as ET
from collections import defaultdict
# python regular expression module
import re 
import pprint
OSM_FILE = open("southampton.osm", "r")

# \S: matches any non-whitespace character
# \.: matches any character except a newline
# $: Occur at the end of string.

street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
street_types = defaultdict(set)

expected =["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road","Trail", "Parkway", "Commons", "Circle", "Way"]

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        #street_types[street_type] += 1
        if street_type not in expected:
            #tracking unusual street type
            street_types[street_type].add(street_name)
            #return True if need to be updated
            return True
def print_sorted_dict(d):
    keys = d.keys()
    keys = sorted(keys, key=lambda s: s.lower())
    for k in keys:
        v = d[k]
        print ("%s: %d" % (k, v) )
# checking k attribute in same tag.
def is_street_name(elem):
    #return (elem.tag == "tag") and (elem.attrib['k'] == "addr:street")
    return (elem.attrib['k'] == "addr:street") or (elem.attrib['k'] == "addr:full")

#create a records of all street types that we find in .osm dataset
def audit():
    # start means start tag. so generate next tag (elem "object type")
    for event, elem in ET.iterparse(OSM_FILE, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            #return iteration all of sub tags ( nested in elem object) named tag only.
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                # v is an attribute in tag
                    audit_street_type(street_types, tag.attrib['v'])    
    #print_sorted_dict(street_types) # uncomment if wanted to count the frequancey of each name.   
    pprint.pprint(dict(street_types))

if __name__ == '__main__':
    audit()
# Out:
# {'2HW': {'11-13 and 19-22 Market Buildings, High Road, Swaythling, '
#          'Southampton, SO16 2HW',
#          '2-3 Market Buildings, High Road, Swaythling, Southampton, SO16 2HW',
#          '5 Market Buildings, High Road, Swaythling, Southampton, SO16 2HW',
#          'Market Buildings, High Road, Swaythling, Southampton, SO16 2HW'},
#  '387': {'387'},
#  'Bridge': {'Horseshoe Bridge'},
#  'Broadway': {'Midanbury Broadway', 'The Broadway'},
#  'Buildings': {'Hanover Buildings', 'Gordon Buildings', 'Market Buildings'},
#  'Centre': {'The Marlands Shopping Centre', 'Townhill Farm District Centre'},
#  'Cloisters': {'The Cloisters'},
#  'Close': {'Abbotsfield Close',
#            'Aldermoor Close',
#            'Andes Close',
#            'Arnheim Close',
#            'Ashridge Close',
#            'Atlantic Close',
#            'Bassett Close',
#            'Bealing Close',
#            'Beaumont Close',
#            'Bembridge Close',
#            'Berkeley Close',
#            'Berwick Close',
#            'Bevan Close',
#            'Binsey Close',
#            'Binstead Close',
#            'Blackbushe Close',
#            'Bleaklow Close',
#            'Bonchurch Close',
#            'Boundary Close',
#            'Brading Close',
#            'Brighstone Close',
#            'Canford Close',
#            'Castleshaw Close',
#            'Cateran Close',
#            'Charles Arden Close',
#            'Cleasby Close',
#            'Collier Close',
#            'Cranbourne Close',
#            'Crigdon Close',
#            'Crofton Close',
#            'Culver Close',
#            'Curlew Close',
#            'Dale Valley Close',
#            'Dawnay Close',
#            'Dimond Close',
#            'Drayton Close',
#            'Duncan Close',
#            'Dunkirk Close',
#            'Ellwood Close',
#            'Falaise Close',
#            'Fernside Close',
#            'Field Close',
#            'Firecrest Close',
#            'Fulmar Close',
#            'Fyeford Close',
#            'Gilpin Close',
#            'Glen Eyre Close',
#            'Grosvenor Close',
#            'Hameldon Close',
#            'Hardy Close',
#            'Harrier Close',
#            'Hawfinch Close',
#            'Herrick Close',
#            'Highfield Close',
#            'Holly Hill Close',
#            'Hollybrook Close',
#            'Honister Close',
#            'Horder Close',
#            'Hunton Close',
#            'Hyde Close',
#            'Kilarney Close',
#            'Killarney Close',
#            'Langdale Close',
#            'Legion Close',
#            'Leroux Close',
#            'Lingwood Close',
#            'Lordswood Close',
#            'Lulworth Close',
#            'Norham Close',
#            'Pacific Close',
#            'Peak Close',
#            'Pembrey Close',
#            'Pendle Close',
#            'Pirrie Close',
#            'Plover Close',
#            'Pointout Close',
#            'Priory Close',
#            'Proctor Close',
#            'Redhill Close',
#            'Ridding Close',
#            'Royston Close',
#            'Sanctuary Close',
#            'Seagarth Close',
#            'Seymour Close',
#            'Shawford Close',
#            'Sherwood Close',
#            'Somerford Close',
#            'Spindlewood Close',
#            'St James Close',
#            "St James's Close",
#            "St Martin's Close",
#            'Staplehurst Close',
#            'Stoneham Close',
#            'Talbot Close',
#            'Tasman Close',
#            'Tosson Close',
#            'Tudor Wood Close',
#            'Underwood Close',
#            'Vaudrey Close',
#            'Vermont Close',
#            'Whernside Close',
#            'Whitestone Close',
#            'Wykeham Close',
#            'York Close'},
#  'Cottages': {'Honeysuckle Cottages'},
#  'Crescent': {'Alcantara Crescent',
#               'Ashley Crescent',
#               'Blighmont Crescent',
#               'Boniface Crescent',
#               'Carlton Crescent',
#               'Chelveston Crescent',
#               'Cheviot Crescent',
#               'Cobden Crescent',
#               'Evelyn Crescent',
#               'Gerard Crescent',
#               'Greenlea Crescent',
#               'Harland Crescent',
#               'Highfield Crescent',
#               'Linford Crescent',
#               'Mead Crescent',
#               'Munro Crescent',
#               'Radway Crescent',
#               'Redhill Crescent',
#               'Shanklin Crescent',
#               'Spring Crescent',
#               'Tatwin Crescent',
#               'Victory Crescent',
#               'Westbourne Crescent',
#               'Wilton Crescent',
#               'evelyn Crescent'},
#  'Dell': {'Holly Dell'},
#  'Drove': {'Coxford Drove', 'York Drove'},
#  'East': {'Bassett Crescent East', 'Bitterne Road East', 'Millbrook Road East'},
#  'Esplanade': {'Western Esplanade'},
#  'Estate': {'Belgrave Industrial Estate'},
#  'Finches': {'The Finches'},
#  'Firs': {'The Firs'},
#  'Gardens': {'Abercrombie Gardens',
#              'Abingdon Gardens',
#              'Ashwood Gardens',
#              'Bassett Gardens',
#              'Bevois Gardens',
#              'Blenheim Gardens',
#              'Burgess Gardens',
#              'Charles Knott Gardens',
#              'Dale Valley Gardens',
#              'Darlington Gardens',
#              'Denbigh Gardens',
#              'Elmsleigh Gardens',
#              'Fernlea Gardens',
#              'Fuchsia Gardens',
#              'Grafton Gardens',
#              'Grosvenor Gardens',
#              'Janaway Gardens',
#              'Lordswood Gardens',
#              'Mayfair Gardens',
#              'Mill Gardens',
#              'Northlands Gardens',
#              'Northolt Gardens',
#              'Osborne Gardens',
#              'Pettinger Gardens',
#              'Ranelagh Gardens',
#              'Rayners Gardens',
#              'Richmond Gardens',
#              'Ripstone Gardens',
#              'Roselands Gardens',
#              'Seacole Gardens',
#              'Sherwood Court, Ticonderoga Gardens',
#              'Shinewill Gardens',
#              'St Augustine Gardens',
#              'Summerfield Gardens',
#              'Tower Gardens',
#              'Undercliff Gardens',
#              'Vinery Gardens',
#              'Wilton Gardens',
#              'Yarmouth Gardens'},
#  'Green': {'Chiltern Green', 'Lulworth Green', 'Edwin Jones Green'},
#  'Greenways': {'Greenways'},
#  'Grove': {'Cavendish Grove',
#            'Donnington Grove',
#            'Granby Grove',
#            'Hartley Grove',
#            "Howard's Grove",
#            'Howards Grove',
#            'Nightingale Grove',
#            'Vincents Grove',
#            'Walnut Grove'},
#  'High-Rise': {'Ferry High-Rise'},
#  'Hill': {'Abbey Hill',
#           'Bevois Hill',
#           'Holly Hill',
#           'Redbridge Hill',
#           'Witts Hill'},
#  'Holt': {'Aspen Holt'},
#  'House': {'Beech House'},
#  'Loop': {'Spitfire Loop'},
#  'Mayflowers': {'The Mayflowers'},
#  'Meadow': {'Bassett Meadow'},
#  'Mews': {'Clifford Dibben Mews',
#           'Court Royal Mews',
#           'Fairfax Mews',
#           'Grosvenor Mews',
#           'Highcrown Mews',
#           'Joiners Mews',
#           'Old Cricket Mews',
#           'Sirdar Mews',
#           'Westcliff Mews'},
#  'Mount': {'The Mount'},
#  'North': {'Osborne Road North', 'Manor Road North'},
#  'Parade': {'Marine Parade', 'Harbour Parade'},
#  'Park': {'Antelope Park', 'Portswood Park'},
#  'Polygon': {'The Polygon'},
#  'Precinct': {'Shirley Precinct'},
#  'Quay': {'Town Quay', 'Shamrock Quay'},
#  'Queensway': {'Queensway'},
#  'Raod': {'Bluebell Raod'},
#  'Rd': {'Grange Rd', 'Bellevue Rd', 'Hythe Rd'},
#  'Redhill': {'Redhill'},
#  'Rise': {'Overcliff Rise'},
#  'S': {'S'},
#  'Saltmead': {'Saltmead'},
#  'South': {'Albert Road South', 'Osborne Road South'},
#  'Street)': {'Western Esplanade (corner of Fitzhugh Street)'},
#  'Terrace': {'Anglesea Terrace',
#              'Blechynden Terrace',
#              "Brinton's Terrace",
#              'Brintons Terrace',
#              'Cranbury Terrace',
#              'East Park Terrace',
#              'Handel Terrace',
#              'Porland Terrace',
#              'Portland Terrace',
#              'Terminus Terrace'},
#  'View': {'Pond View', 'Park View'},
#  'Village': {'Bassett Green Road / Bassett Green Village',
#              'Bitterne Village',
#              'Ocean Village'},
#  'Walk': {'Canal Walk',
#           'Cherry Walk',
#           'Maritime Walk',
#           'Mulberry Walk',
#           'Squires Walk',
#           'Vernon Walk',
#           'Vincents Walk'},
#  'West': {'Bassett Crescent West', 'Millbrook Road West', 'Bitterne Road West'},
#  'Westal': {'Bitterne Road Westal'},
#  'access': {'Emergency department access'},
#  're': {'Royal Crescent Road student re'},
#  'road': {'Bluebell road', 'bluebell road'}}

# %% [markdown]
# ##### Develop plan for cleaning.
# I guess 2HW is an area in southampton so I googled the address
# where the result met my expectation so I will convert it to High Road which is the correct strret name.
# No idea about the meaning of S and re, so I will ignore them.
#
# mapping = { "2HW": "HighRoad",
#             "Raod": "Road",
#             "Rd": "Road",
#             "Street)":"Street",
#             "road":"Road",
#             "Road Westal":"Road West"
#           }

# %%
# %load improve_street.py

"""""
4- Improving Street Names
"""""
import xml.etree.cElementTree as ET
from collections import defaultdict
from __future__ import division, absolute_import, print_function, unicode_literals
import re
import pprint

OSMFILE = "southampton.osm"
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons"]

mapping = { "2HW": "HighRoad",
            "Raod": "Road",
            "Rd": "Road",
            "Street)":"Street",
            "road":"Road",
            "Road Westal":"Road West"
          }


def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
                    tag.attrib['v'] = update_name(tag.attrib['v'],mapping)

    osm_file.close()
    return street_types


def update_name(name, mapping):

    dictionary_map = sorted(mapping.keys(), key=len, reverse=True)
    for key in dictionary_map:
        
        if name.find(key) != -1:          
            name = name.replace(key,mapping[key])

    return name


def test():
    st_types = audit(OSMFILE)
    #assert len(st_types) == 6
    #pprint.pprint(dict(st_types))
    # in python 3: iteritems =>>> items 
    for st_type, ways in st_types.items():
        for name in ways:
            better_name = update_name(name, mapping)
            print (name, "=>", better_name)
            if name == "Bluebell Raod":
                assert better_name == "Bluebell Road"
            if name == "Hythe Rd":
                assert better_name == "Hythe Road"


if __name__ == '__main__':
    test()
# Out:
# Albert Road South => Albert Road South
# Osborne Road South => Osborne Road South
# Asturias Way => Asturias Way
# Redwood Way => Redwood Way
# Redhill Way => Redhill Way
# Normandy Way => Normandy Way
# Rudd Way => Rudd Way
# Channel Way => Channel Way
# Ocean Way => Ocean Way
# Thomas Lewis Way => Thomas Lewis Way
# Woodlands Way => Woodlands Way
# International Way => International Way
# Pentire Way => Pentire Way
# Pine Way => Pine Way
# Teboura Way => Teboura Way
# leaside Way => leaside Way
# Hadrian Way => Hadrian Way
# Leaside Way => Leaside Way
# Glen Eyre Way => Glen Eyre Way
# Lord's Hill Way => Lord's Hill Way
# Oriana Way => Oriana Way
# Lower Brownhill Way => Lower Brownhill Way
# Cranford Way => Cranford Way
# Monks Way => Monks Way
# Uplands Way => Uplands Way
# Abbotts Way => Abbotts Way
# Marvin Way => Marvin Way
# Castle Way => Castle Way
# Brookside Way => Brookside Way
# Orchards Way => Orchards Way
# Oaklands Way => Oaklands Way
# Glencarron Way => Glencarron Way
# Cumbrian Way => Cumbrian Way
# Vernon Walk => Vernon Walk
# Vincents Walk => Vincents Walk
# Squires Walk => Squires Walk
# Canal Walk => Canal Walk
# Cherry Walk => Cherry Walk
# Mulberry Walk => Mulberry Walk
# Maritime Walk => Maritime Walk
# Bassett Close => Bassett Close
# Proctor Close => Proctor Close
# Fyeford Close => Fyeford Close
# Falaise Close => Falaise Close
# Firecrest Close => Firecrest Close
# Tudor Wood Close => Tudor Wood Close
# Grosvenor Close => Grosvenor Close
# Honister Close => Honister Close
# Tasman Close => Tasman Close
# Abbotsfield Close => Abbotsfield Close
# Curlew Close => Curlew Close
# Kilarney Close => Kilarney Close
# Sherwood Close => Sherwood Close
# Lulworth Close => Lulworth Close
# Hollybrook Close => Hollybrook Close
# Ridding Close => Ridding Close
# Binsey Close => Binsey Close
# Fulmar Close => Fulmar Close
# Glen Eyre Close => Glen Eyre Close
# Tosson Close => Tosson Close
# St James Close => St James Close
# Binstead Close => Binstead Close
# Field Close => Field Close
# Brighstone Close => Brighstone Close
# Redhill Close => Redhill Close
# Pembrey Close => Pembrey Close
# Aldermoor Close => Aldermoor Close
# Talbot Close => Talbot Close
# Bevan Close => Bevan Close
# Wykeham Close => Wykeham Close
# Harrier Close => Harrier Close
# Whernside Close => Whernside Close
# Priory Close => Priory Close
# Gilpin Close => Gilpin Close
# Shawford Close => Shawford Close
# Underwood Close => Underwood Close
# Cateran Close => Cateran Close
# Bonchurch Close => Bonchurch Close
# Highfield Close => Highfield Close
# Vermont Close => Vermont Close
# Pointout Close => Pointout Close
# Charles Arden Close => Charles Arden Close
# Collier Close => Collier Close
# St Martin's Close => St Martin's Close
# Hameldon Close => Hameldon Close
# Dawnay Close => Dawnay Close
# Staplehurst Close => Staplehurst Close
# Crigdon Close => Crigdon Close
# Legion Close => Legion Close
# Hyde Close => Hyde Close
# Pirrie Close => Pirrie Close
# Atlantic Close => Atlantic Close
# Ashridge Close => Ashridge Close
# Stoneham Close => Stoneham Close
# Dale Valley Close => Dale Valley Close
# Castleshaw Close => Castleshaw Close
# Plover Close => Plover Close
# Beaumont Close => Beaumont Close
# Dimond Close => Dimond Close
# Arnheim Close => Arnheim Close
# Sanctuary Close => Sanctuary Close
# Duncan Close => Duncan Close
# Crofton Close => Crofton Close
# Peak Close => Peak Close
# Horder Close => Horder Close
# Whitestone Close => Whitestone Close
# Bleaklow Close => Bleaklow Close
# Langdale Close => Langdale Close
# Fernside Close => Fernside Close
# Hawfinch Close => Hawfinch Close
# Brading Close => Brading Close
# Vaudrey Close => Vaudrey Close
# Cleasby Close => Cleasby Close
# Ellwood Close => Ellwood Close
# Hunton Close => Hunton Close
# Canford Close => Canford Close
# Bembridge Close => Bembridge Close
# Lingwood Close => Lingwood Close
# Leroux Close => Leroux Close
# Pacific Close => Pacific Close
# Berkeley Close => Berkeley Close
# York Close => York Close
# Royston Close => Royston Close
# Somerford Close => Somerford Close
# Drayton Close => Drayton Close
# Spindlewood Close => Spindlewood Close
# Herrick Close => Herrick Close
# Norham Close => Norham Close
# Dunkirk Close => Dunkirk Close
# Pendle Close => Pendle Close
# Seagarth Close => Seagarth Close
# Boundary Close => Boundary Close
# Killarney Close => Killarney Close
# Berwick Close => Berwick Close
# St James's Close => St James's Close
# Hardy Close => Hardy Close
# Seymour Close => Seymour Close
# Andes Close => Andes Close
# Blackbushe Close => Blackbushe Close
# Cranbourne Close => Cranbourne Close
# Lordswood Close => Lordswood Close
# Bealing Close => Bealing Close
# Holly Hill Close => Holly Hill Close
# Culver Close => Culver Close
# Handel Terrace => Handel Terrace
# Terminus Terrace => Terminus Terrace
# Blechynden Terrace => Blechynden Terrace
# East Park Terrace => East Park Terrace
# Anglesea Terrace => Anglesea Terrace
# Brintons Terrace => Brintons Terrace
# Cranbury Terrace => Cranbury Terrace
# Brinton's Terrace => Brinton's Terrace
# Portland Terrace => Portland Terrace
# Porland Terrace => Porland Terrace
# Bassett Crescent West => Bassett Crescent West
# Millbrook Road West => Millbrook Road West
# Bitterne Road West => Bitterne Road West
# Bassett Crescent East => Bassett Crescent East
# Bitterne Road East => Bitterne Road East
# Millbrook Road East => Millbrook Road East
# Bitterne Village => Bitterne Village
# Ocean Village => Ocean Village
# Bassett Green Road / Bassett Green Village => Bassett Green Road / Bassett Green Village
# Northlands Gardens => Northlands Gardens
# Denbigh Gardens => Denbigh Gardens
# Wilton Gardens => Wilton Gardens
# Abingdon Gardens => Abingdon Gardens
# Elmsleigh Gardens => Elmsleigh Gardens
# Lordswood Gardens => Lordswood Gardens
# Charles Knott Gardens => Charles Knott Gardens
# Northolt Gardens => Northolt Gardens
# Seacole Gardens => Seacole Gardens
# Fuchsia Gardens => Fuchsia Gardens
# Vinery Gardens => Vinery Gardens
# Mill Gardens => Mill Gardens
# Dale Valley Gardens => Dale Valley Gardens
# Shinewill Gardens => Shinewill Gardens
# Grafton Gardens => Grafton Gardens
# Abercrombie Gardens => Abercrombie Gardens
# Ranelagh Gardens => Ranelagh Gardens
# St Augustine Gardens => St Augustine Gardens
# Bassett Gardens => Bassett Gardens
# Ashwood Gardens => Ashwood Gardens
# Fernlea Gardens => Fernlea Gardens
# Undercliff Gardens => Undercliff Gardens
# Richmond Gardens => Richmond Gardens
# Mayfair Gardens => Mayfair Gardens
# Burgess Gardens => Burgess Gardens
# Summerfield Gardens => Summerfield Gardens
# Blenheim Gardens => Blenheim Gardens
# Bevois Gardens => Bevois Gardens
# Darlington Gardens => Darlington Gardens
# Tower Gardens => Tower Gardens
# Janaway Gardens => Janaway Gardens
# Grosvenor Gardens => Grosvenor Gardens
# Sherwood Court, Ticonderoga Gardens => Sherwood Court, Ticonderoga Gardens
# Pettinger Gardens => Pettinger Gardens
# Rayners Gardens => Rayners Gardens
# Roselands Gardens => Roselands Gardens
# Osborne Gardens => Osborne Gardens
# Ripstone Gardens => Ripstone Gardens
# Yarmouth Gardens => Yarmouth Gardens
# S => S
# Town Quay => Town Quay
# Shamrock Quay => Shamrock Quay
# Osborne Road North => Osborne Road North
# Manor Road North => Manor Road North
# The Marlands Shopping Centre => The Marlands Shopping Centre
# Townhill Farm District Centre => Townhill Farm District Centre
# Shirley Precinct => Shirley Precinct
# Cheviot Crescent => Cheviot Crescent
# Tatwin Crescent => Tatwin Crescent
# Boniface Crescent => Boniface Crescent
# Redhill Crescent => Redhill Crescent
# Harland Crescent => Harland Crescent
# Spring Crescent => Spring Crescent
# Highfield Crescent => Highfield Crescent
# Gerard Crescent => Gerard Crescent
# Shanklin Crescent => Shanklin Crescent
# Victory Crescent => Victory Crescent
# Blighmont Crescent => Blighmont Crescent
# Alcantara Crescent => Alcantara Crescent
# Munro Crescent => Munro Crescent
# Evelyn Crescent => Evelyn Crescent
# Wilton Crescent => Wilton Crescent
# Mead Crescent => Mead Crescent
# Ashley Crescent => Ashley Crescent
# Radway Crescent => Radway Crescent
# Cobden Crescent => Cobden Crescent
# Linford Crescent => Linford Crescent
# Chelveston Crescent => Chelveston Crescent
# Westbourne Crescent => Westbourne Crescent
# Carlton Crescent => Carlton Crescent
# Greenlea Crescent => Greenlea Crescent
# evelyn Crescent => evelyn Crescent
# The Polygon => The Polygon
# Hanover Buildings => Hanover Buildings
# Gordon Buildings => Gordon Buildings
# Market Buildings => Market Buildings
# Grange Rd => Grange Road
# Bellevue Rd => Bellevue Road
# Hythe Rd => Hythe Road
# Holly Hill => Holly Hill
# Redbridge Hill => Redbridge Hill
# Bevois Hill => Bevois Hill
# Witts Hill => Witts Hill
# Abbey Hill => Abbey Hill
# Western Esplanade => Western Esplanade
# Royal Crescent Road student re => Royal Crescent Road student re
# Ferry High-Rise => Ferry High-Rise
# Queensway => Queensway
# Pond View => Pond View
# Park View => Park View
# Chiltern Green => Chiltern Green
# Lulworth Green => Lulworth Green
# Edwin Jones Green => Edwin Jones Green
# Bitterne Road Westal => Bitterne Road West
# Antelope Park => Antelope Park
# Portswood Park => Portswood Park
# Emergency department access => Emergency department access
# Cavendish Grove => Cavendish Grove
# Howards Grove => Howards Grove
# Howard's Grove => Howard's Grove
# Granby Grove => Granby Grove
# Vincents Grove => Vincents Grove
# Nightingale Grove => Nightingale Grove
# Donnington Grove => Donnington Grove
# Hartley Grove => Hartley Grove
# Walnut Grove => Walnut Grove
# Western Esplanade (corner of Fitzhugh Street) => Western Esplanade (corner of Fitzhugh Street
# Midanbury Broadway => Midanbury BRoadway
# The Broadway => The BRoadway
# Joiners Mews => Joiners Mews
# Old Cricket Mews => Old Cricket Mews
# Grosvenor Mews => Grosvenor Mews
# Court Royal Mews => Court Royal Mews
# Westcliff Mews => Westcliff Mews
# Highcrown Mews => Highcrown Mews
# Fairfax Mews => Fairfax Mews
# Clifford Dibben Mews => Clifford Dibben Mews
# Sirdar Mews => Sirdar Mews
# Marine Parade => Marine Parade
# Harbour Parade => Harbour Parade
# The Finches => The Finches
# Saltmead => Saltmead
# Bluebell Raod => Bluebell Road
# Bluebell road => Bluebell Road
# bluebell road => bluebell Road
# Honeysuckle Cottages => Honeysuckle Cottages
# The Cloisters => The Cloisters
# The Mayflowers => The Mayflowers
# Aspen Holt => Aspen Holt
# Coxford Drove => Coxford Drove
# York Drove => York Drove
# Greenways => Greenways
# Holly Dell => Holly Dell
# The Firs => The Firs
# Bassett Meadow => Bassett Meadow
# Beech House => Beech House
# Horseshoe Bridge => Horseshoe Bridge
# Belgrave Industrial Estate => Belgrave Industrial Estate
# 387 => 387
# The Mount => The Mount
# Spitfire Loop => Spitfire Loop
# Redhill => Redhill
# Overcliff Rise => Overcliff Rise

# %%
#%load data.py
"""""
4- Preparing for Database - MongoDB
"""""

import xml.etree.ElementTree as ET 
import pprint 
import re 
import codecs 
import json 
import sys 

OSM_FILE = 'southampton.osm'  
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


CREATED = [ "version", "changeset", "timestamp", "user", "uid"] 
 
 
 
def shape_element(element): 
    node = {} 
     # you should process only 2 types of top level tags: "node" and "way" 
    if element.tag == "node" or element.tag == "way" : 
        #create the dictionary based on exaclty the value in element attribute.
        for key in element.attrib.keys(): 
            val = element.attrib[key] 
            node["type"] = element.tag 
            if key in CREATED: 
                if not "created" in node.keys(): 
                    node["created"] = {} 
                node["created"][key] = val 
            elif key == "lat" or key == "lon": 
                if not "pos" in node.keys(): 
                    node["pos"] = [0.0, 0.0] 
                old_pos = node["pos"] 
                if key == "lat": 
                    new_pos = [float(val), old_pos[1]] 
                else: 
                    new_pos = [old_pos[0], float(val)] 
                node["pos"] = new_pos 
            else: 
                node[key] = val 
            for tag in element.iter("tag"): 
                tag_key = tag.attrib['k'] 
                tag_val = tag.attrib['v'] 
                if problemchars.match(tag_key): 
                    continue 
                elif tag_key.startswith("addr:"): 
                    if not "address" in node.keys(): 
                        node["address"] = {} 
                    addr_key = tag.attrib['k'][len("addr:") : ] 
                    if lower_colon.match(addr_key): 
                        continue 
                    else: 
                        node["address"][addr_key] = tag_val 
                elif lower_colon.match(tag_key): 
                    node[tag_key] = tag_val 
                else: 
                    node[tag_key] = tag_val 
        for tag in element.iter("nd"): 
            if not "node_refs" in node.keys(): 
                node["node_refs"] = [] 
            node_refs = node["node_refs"] 
            node_refs.append(tag.attrib["ref"]) 
            node["node_refs"] = node_refs 
 
 
        return node 
    else: 
        return None 
 
 
 
 # Process the osm file to json file to be prepared for input file to monggo

def process_map(file_in, pretty = False): 
    # You do not need to change this file 
    file_out = "{0}.json".format(file_in) 
    data = [] 
    with codecs.open(file_out, "w") as fo: 
        for _, element in ET.iterparse(file_in): 
            el = shape_element(element) 
            if el: 
                data.append(el) 
                if pretty: 
                    fo.write(json.dumps(el, indent=2)+"\n") 
                else: 
                    fo.write(json.dumps(el) + "\n") 
    return data 

 
def run(): 
    data = process_map(OSM_FILE, False) 
    pprint.pprint(data[2]) # uncomment for checking data format before transfar it into MongoDB

    
if __name__ == "__main__": 
    run ()
    
    
#print (run(osm_file))    
#  if __name__ == "__main__": 
#     if not len(sys.argv) == 2: 
#          print "Usage: python maps/data.py input-file" 
#     else: 
#          run(sys.argv[1])
# Out:
# {'created': {'changeset': '153019',
#              'timestamp': '2006-11-11T17:21:36Z',
#              'uid': '2231',
#              'user': 'Deanna Earley',
#              'version': '1'},
#  'id': '132709',
#  'pos': [50.9507933, -1.4643494],
#  'type': 'node'}

# %%
from data import *
data = process_map(OSM_FILE, False) 
pprint.pprint(data[:4]) # checking data format before transfar it into MongoDB
# Out:
# [{'created': {'changeset': '8139974',
#               'timestamp': '2011-05-14T11:45:29Z',
#               'uid': '260682',
#               'user': 'monxton',
#               'version': '5'},
#   'id': '132707',
#   'pos': [50.9454657, -1.4775675],
#   'type': 'node'},
#  {'created': {'changeset': '153019',
#               'timestamp': '2006-11-11T17:58:16Z',
#               'uid': '2231',
#               'user': 'Deanna Earley',
#               'version': '1'},
#   'id': '132708',
#   'pos': [50.9474216, -1.4709162],
#   'type': 'node'},
#  {'created': {'changeset': '153019',
#               'timestamp': '2006-11-11T17:21:36Z',
#               'uid': '2231',
#               'user': 'Deanna Earley',
#               'version': '1'},
#   'id': '132709',
#   'pos': [50.9507933, -1.4643494],
#   'type': 'node'},
#  {'created': {'changeset': '153019',
#               'timestamp': '2006-11-11T17:24:45Z',
#               'uid': '2231',
#               'user': 'Deanna Earley',
#               'version': '1'},
#   'id': '132710',
#   'pos': [50.9533581, -1.4594265],
#   'type': 'node'}]

# %%
"""""
4- ACCESSING MongoDB
>> Point your command prompt to C:\Program Files\MongoDB\Server\3.4\bin
>> mongo.exe
http://stackoverflow.com/questions/23726684/mongodb-on-a-windows-7-machine-no-connection-could-be-made
"""""

from pymongo import MongoClient

#client  = MongoClient('mongodb://localhost:27017')
client  = MongoClient()

# Access Database Objects
db = client.southampton

# %%
# Insert a document into a collection named southampton in MongoDB.
[db.southampton.insert(e) for e in data]
# Out:
# C:\Users\meto\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-28-d686fcbca2d1> in <module>()
#       1 # Insert a document into a collection named southampton in MongoDB.
# ----> 2 [db.southampton.insert(e) for e in data]
#
# <ipython-input-28-d686fcbca2d1> in <listcomp>(.0)
#       1 # Insert a document into a collection named southampton in MongoDB.
# ----> 2 [db.southampton.insert(e) for e in data]
#
# C:\Users\meto\Anaconda3\lib\site-packages\pymongo\collection.py in insert(self, doc_or_docs, manipulate, check_keys, continue_on_error, **kwargs)
#    2465         if kwargs:
#    2466             write_concern = WriteConcern(**kwargs)
# -> 2467         with self._socket_for_writes() as sock_info:
#    2468             return self._insert(sock_info, doc_or_docs, not continue_on_error,
#    2469                                 check_keys, manipulate, write_concern)
#
# C:\Users\meto\Anaconda3\lib\contextlib.py in __enter__(self)
#      80     def __enter__(self):
#      81         try:
# ---> 82             return next(self.gen)
#      83         except StopIteration:
#      84             raise RuntimeError("generator didn't yield") from None
#
# C:\Users\meto\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _get_socket(self, selector)
#     821     @contextlib.contextmanager
#     822     def _get_socket(self, selector):
# --> 823         server = self._get_topology().select_server(selector)
#     824         try:
#     825             with server.get_socket(self.__all_credentials) as sock_info:
#
# C:\Users\meto\Anaconda3\lib\site-packages\pymongo\topology.py in select_server(self, selector, server_selection_timeout, address)
#     212         return random.choice(self.select_servers(selector,
#     213                                                  server_selection_timeout,
# --> 214                                                  address))
#     215
#     216     def select_server_by_address(self, address,
#
# C:\Users\meto\Anaconda3\lib\site-packages\pymongo\topology.py in select_servers(self, selector, server_selection_timeout, address)
#     187                 if server_timeout == 0 or now > end_time:
#     188                     raise ServerSelectionTimeoutError(
# --> 189                         self._error_message(selector))
#     190
#     191                 self._ensure_opened()
#
# ServerSelectionTimeoutError: localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it

# %%
# Thoroughness and Succinctness of Submission

def find():
    x={"highway": "residential"}
    resdient = db.southampton.find(x)
    for r in resdient:
        pprint.pprint(r)
        
if __name__ == '__main__':
    find()
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-29-db6b43d4dea1> in <module>()
#       8
#       9 if __name__ == '__main__':
# ---> 10     find()
#
# <ipython-input-29-db6b43d4dea1> in find()
#       4     x={"highway": "residential"}
#       5     resdient = db.southampton.find(x)
# ----> 6     for r in resdient:
#       7         pprint.pprint(r)
#       8
#
# C:\Users\meto\Anaconda3\lib\site-packages\pymongo\cursor.py in next(self)
#    1112             raise StopIteration
#    1113         _db = self.__collection.database
# -> 1114         if len(self.__data) or self._refresh():
#    1115             if self.__manipulate:
#    1116                 return _db._fix_outgoing(self.__data.popleft(),
#
# C:\Users\meto\Anaconda3\lib\site-packages\pymongo\cursor.py in _refresh(self)
#    1034                                        self.__batch_size,
#    1035                                        self.__read_concern,
# -> 1036                                        self.__collation))
#    1037             if not self.__id:
#    1038                 self.__killed = True
#
# C:\Users\meto\Anaconda3\lib\site-packages\pymongo\cursor.py in __send_message(self, operation)
#     871             try:
#     872                 response = client._send_message_with_response(operation,
# --> 873                                                               **kwargs)
#     874                 self.__address = response.address
#     875                 if self.__exhaust:
#
# C:\Users\meto\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _send_message_with_response(self, operation, read_preference, exhaust, address)
#     886         else:
#     887             selector = read_preference or writable_server_selector
# --> 888             server = topology.select_server(selector)
#     889
#     890         # A _Query's slaveOk bit is already set for queries with non-primary
#
# C:\Users\meto\Anaconda3\lib\site-packages\pymongo\topology.py in select_server(self, selector, server_selection_timeout, address)
#     212         return random.choice(self.select_servers(selector,
#     213                                                  server_selection_timeout,
# --> 214                                                  address))
#     215
#     216     def select_server_by_address(self, address,
#
# C:\Users\meto\Anaconda3\lib\site-packages\pymongo\topology.py in select_servers(self, selector, server_selection_timeout, address)
#     187                 if server_timeout == 0 or now > end_time:
#     188                     raise ServerSelectionTimeoutError(
# --> 189                         self._error_message(selector))
#     190
#     191                 self._ensure_opened()
#
# ServerSelectionTimeoutError: localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it

# %% [markdown]
# # 2. Data Overview

# %%
"""
FILE SIZE.

"""

import os
os.path.getsize('southampton.osm')


# OR:
# statinfo = os.stat(OSM_FILE)
# #print (statinfo)
# statinfo.st_size
# Out:
# 66903798

# %%
""""
Number of documents

""""

# count() is equivalent to the db.collection.find(query).count() construct.
db.southampton.find().count()
# Out:
# 324000

# %%
"""
Number of nodes

"""

db.southampton.find({"type":"node"}).count()
# Out:
# 272641

# %%
"""
Number of ways

"""

db.southampton.find({"type":"way"}).count()
# Out:
# 51354

# %%
"""
Number of unique users

"""
                                                
db.southampton.distinct({"created.user"}).length
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-f12d1db1ce02> in <module>()
#       4 """
#       5
# ----> 6 db.southampton.distinct({"created.user"}).length
#
# C:\Users\meto\Anaconda3\lib\site-packages\pymongo\collection.py in distinct(self, key, filter, **kwargs)
#    2016         if not isinstance(key, string_type):
#    2017             raise TypeError("key must be an "
# -> 2018                             "instance of %s" % (string_type.__name__,))
#    2019         cmd = SON([("distinct", self.__name),
#    2020                    ("key", key)])
#
# TypeError: key must be an instance of str

# %%
import os
statinfo = os.stat(OSM_FILE)
#print (statinfo)
statinfo.st_size
# Out:
# 66903798

# %%
db.stats
function (scale){
    return this.runCommand({dbstats:1, scale:scale});
}
